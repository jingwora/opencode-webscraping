# %% [markdown]
# ## finance.yahoo.co.jp

# %%
import pandas as pd

# %%
url = 'https://finance.yahoo.co.jp/'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df
# Out:
# No. of Table:  1
#                                                    0  ...                                                 3
# 0  値上がり率2332社1. アライドＴ+33.33％2. ウインテス+29.24％3. アウン...  ...  銘柄別投稿数1. テラ2. アンジェス3. サンバイオ4. エイミング5. ソフトＢＧもっと見る
#
# [1 rows x 4 columns]

# %%
url = 'https://info.finance.yahoo.co.jp/ranking/?kd=4'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df.head(5)
# Out:
# No. of Table:  1
#   順位   コード    市場             名称    取引値  取引値.1     発行済み株式数 時価総額（百万円） 単元株数  掲示板
# 0  1  7203  東証1部      トヨタ自動車(株)  09/16   7064  3262997492  23049814  100  掲示板
# 1  2  9984  東証1部  ソフトバンクグループ(株)  09/16   6704  2089814330  14010115  100  掲示板
# 2  3  6861  東証1部       (株)キーエンス  09/16  45370   243207684  11034333  100  掲示板
# 3  4  6758  東証1部         ソニー(株)  09/16   8210  1261058781  10353293  100  掲示板
# 4  5  9437  東証1部      (株)ＮＴＴドコモ  09/16   2798  3228629406   9033705  100  掲示板
