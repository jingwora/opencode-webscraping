# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Script
#
# Version: 2
#
# url: https://news.yahoo.co.jp/ranking/comment/
#
# output: outputs/news_yyyymmdd_hhmmss.csv
#
# logs: logs/logfile_ws02_%Y%m%d.log

# %%
import os
import sys
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta, timezone
import logging


def create_logging():
  """ Create logging """
  logs_folder = 'logs/'
  if not os.path.exists(logs_folder):
    os.makedirs(logs_folder)

  log_dir = logs_folder + str(datetime.now().strftime('logfile_ws02_%Y%m%d.log'))
  logging.basicConfig(filename=log_dir,
                  level=logging.INFO,
                  format='%(asctime)s | %(name)s | %(levelname)s | %(message)s')
  console = logging.StreamHandler()
  console.setLevel(logging.INFO)
  formatter = logging.Formatter('%(asctime)s | %(name)s | %(levelname)s | %(message)s')
  console.setFormatter(formatter)
  logging.getLogger('').addHandler(console)
  
  logging.info('Started')
  logging.info('Python environment : ' + str(sys.version))
  logging.info('Requests version: ' + str(requests.__version__))
  logging.info('BeautifulSoup version: ' + str(bs4.__version__))
  logging.info('Pandas version: ' + str(pd.__version__))
  logging.info('Log file : ' + str(log_dir))


def yahoo_news_scraping():
  """ Scrap data and return result dataframe """
  #  Set parameters
  home_url = "https://news.yahoo.co.jp/ranking/comment/"
  topics = ['domestic', 'world', 'business', 'entertainment', 'sports', 'it-science', 'life']

  result = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])

  #  Get data
  for t in topics:
    df = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])

    url = home_url + t

    res = requests.get(url)
    logging.info('GET: ' + url)
    logging.info('STATUS: ' + str(res.status_code))

    soup = BeautifulSoup(res.text, 'lxml')

    titles = soup.find_all('div', {'class': 'newsFeed_item_title'})
    datetimes = soup.find_all('time', {'class': 'newsFeed_item_date'})

    # Create dataframe
    df = pd.DataFrame(list(zip(titles, datetimes)), columns =['titles', 'datetimes']) 
    
    spec_chars = ['<div class="newsFeed_item_title">', '</div>']
    for char in spec_chars:
      df['titles'] = df['titles'].astype(str).str.replace(char, ' ')
      
    spec_chars = ['<time class="newsFeed_item_date">', '</time>']
    for char in spec_chars:
      df['datetimes'] = df['datetimes'].astype(str).str.replace(char, ' ')

    df['topics'] = t

    result = pd.concat([result, df])
    logging.info('Finish Scraping')

  return result


def save_csv(result):
  """ Save dataframe to csv """

  jst = timezone(timedelta(hours=9), 'JST')
  now = datetime.now(jst).strftime("%Y%m%d_%H%M%S")
  output_folder = 'outputs/'
  if not os.path.exists(output_folder):
      os.makedirs(output_folder)

  output = output_folder + 'news_' + now + '.csv'

  result.to_csv(output, index=False, encoding='utf_8_sig')
  logging.info('No. of news'  + str(len(result)))
  logging.info('Saved file: ' + output)


if __name__ == '__main__':
    create_logging()
    result = yahoo_news_scraping()
    save_csv(result)
# Out:
# 2020-09-18 03:48:33,098 | root | INFO | Started
# 2020-09-18 03:48:33,100 | root | INFO | Python environment : 3.6.9 (default, Jul 17 2020, 12:50:27)
# [GCC 8.4.0]
# 2020-09-18 03:48:33,105 | root | INFO | Requests version: 2.23.0
# 2020-09-18 03:48:33,106 | root | INFO | BeautifulSoup version: 4.6.3
# 2020-09-18 03:48:33,109 | root | INFO | Pandas version: 1.0.5
# 2020-09-18 03:48:33,111 | root | INFO | Log file : logs/logfile_ws02_20200918.log
# 2020-09-18 03:48:33,475 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/domestic
# 2020-09-18 03:48:33,476 | root | INFO | STATUS: 200
# 2020-09-18 03:48:33,528 | root | INFO | Finish Scraping
# 2020-09-18 03:48:33,807 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/world
# 2020-09-18 03:48:33,808 | root | INFO | STATUS: 200
# 2020-09-18 03:48:33,857 | root | INFO | Finish Scraping
# 2020-09-18 03:48:34,153 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/business
# 2020-09-18 03:48:34,154 | root | INFO | STATUS: 200
# 2020-09-18 03:48:34,204 | root | INFO | Finish Scraping
# 2020-09-18 03:48:34,505 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/entertainment
# 2020-09-18 03:48:34,506 | root | INFO | STATUS: 200
# 2020-09-18 03:48:34,555 | root | INFO | Finish Scraping
# 2020-09-18 03:48:34,894 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/sports
# 2020-09-18 03:48:34,895 | root | INFO | STATUS: 200
# 2020-09-18 03:48:34,946 | root | INFO | Finish Scraping
# 2020-09-18 03:48:35,299 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/it-science
# 2020-09-18 03:48:35,300 | root | INFO | STATUS: 200
# 2020-09-18 03:48:35,352 | root | INFO | Finish Scraping
# 2020-09-18 03:48:35,673 | root | INFO | GET: https://news.yahoo.co.jp/ranking/comment/life
# 2020-09-18 03:48:35,674 | root | INFO | STATUS: 200
# 2020-09-18 03:48:35,724 | root | INFO | Finish Scraping
# 2020-09-18 03:48:35,735 | root | INFO | No. of news280
# 2020-09-18 03:48:35,736 | root | INFO | Saved file: outputs/news_20200918_124835.csv

# %% [markdown]
# ## Script
#
# Version: 1
#
# url: https://news.yahoo.co.jp/topics/
#
# output: outputs/news_yyyymmdd_hhmmss.csv
#
# logs: logs/logfile_ws01_%Y%m%d.log

# %%
import os
import sys
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta, timezone
import logging


def create_logging():
  """ Create logging """
  logs_folder = 'logs/'
  if not os.path.exists(logs_folder):
    os.makedirs(logs_folder)

  logging.basicConfig(filename=datetime.now().strftime('logs/logfile_ws01_%Y%m%d.log'),
                  level=logging.INFO,
                  format='%(asctime)s | %(name)s | %(levelname)s | %(message)s')
  console = logging.StreamHandler()
  console.setLevel(logging.INFO)
  formatter = logging.Formatter('%(asctime)s | %(name)s | %(levelname)s | %(message)s')
  console.setFormatter(formatter)
  logging.getLogger('').addHandler(console)
  
  logging.info('Started')
  logging.info('Python environment : ' + str(sys.version))
  logging.info('Requests version: ' + str(requests.__version__))
  logging.info('BeautifulSoup version: ' + str(bs4.__version__))
  logging.info('Pandas version: ' + str(pd.__version__))


def yahoo_news_scraping():
  """ Scrap data and return result dataframe """
  #  Set parameters
  home_url = "https://news.yahoo.co.jp/topics/"
  topics = ['domestic', 'world', 'business', 'entertainment', 'sports', 'it', 'science']
  page_no = ['/?page=1', '?page=2', '?page=3']

  result = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])

  #  Get data
  for t in topics:
    for p in page_no:
      df = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])

      url = home_url + "/" + t + "/" + p

      res = requests.get(url)
      logging.info('GET: ' + url)
      logging.info('STATUS: ' + str(res.status_code))

      soup = BeautifulSoup(res.text, 'lxml')

      titles = soup.find_all('div', {'class': 'newsFeed_item_title'})
      datetimes = soup.find_all('time', {'class': 'newsFeed_item_date'})

      # Create dataframe
      df = pd.DataFrame(list(zip(titles, datetimes)), columns =['titles', 'datetimes']) 
      
      spec_chars = ['<div class="newsFeed_item_title">', '</div>']
      for char in spec_chars:
        df['titles'] = df['titles'].astype(str).str.replace(char, ' ')
        
      spec_chars = ['<time class="newsFeed_item_date">', '</time>']
      for char in spec_chars:
        df['datetimes'] = df['datetimes'].astype(str).str.replace(char, ' ')

      df['topics'] = t

      result = pd.concat([result, df])
      logging.info('Finish Scraping')

  return result


def save_csv(result):
  """ Save dataframe to csv """

  jst = timezone(timedelta(hours=9), 'JST')
  now = datetime.now(jst).strftime("%Y%m%d_%H%M%S")
  output_folder = 'outputs/'
  if not os.path.exists(output_folder):
      os.makedirs(output_folder)

  output = output_folder + 'news_' + now + '.csv'

  result.to_csv(output, index=False, encoding='utf_8_sig')
  logging.info('No. of news'  + str(len(result)))
  logging.info('Saved file: ' + output)
  logging.info('Logs file: ' + datetime.now().strftime('logs/logfile_ws01_%Y%m%d.log'))


if __name__ == '__main__':
    create_logging()
    result = yahoo_news_scraping()
    save_csv(result)
# Out:
# 2020-09-18 03:00:15,429 | root | INFO | Started
# 2020-09-18 03:00:15,430 | root | INFO | Python environment : 3.6.9 (default, Jul 17 2020, 12:50:27)
# [GCC 8.4.0]
# 2020-09-18 03:00:15,436 | root | INFO | Requests version: 2.23.0
# 2020-09-18 03:00:15,437 | root | INFO | BeautifulSoup version: 4.6.3
# 2020-09-18 03:00:15,441 | root | INFO | Pandas version: 1.0.5
# 2020-09-18 03:00:16,695 | root | INFO | GET: https://news.yahoo.co.jp/topics//domestic//?page=1
# 2020-09-18 03:00:16,696 | root | INFO | STATUS: 404
# 2020-09-18 03:00:16,720 | root | INFO | Finish Scraping
# 2020-09-18 03:00:17,893 | root | INFO | GET: https://news.yahoo.co.jp/topics//domestic/?page=2
# 2020-09-18 03:00:17,894 | root | INFO | STATUS: 200
# 2020-09-18 03:00:17,943 | root | INFO | Finish Scraping
# 2020-09-18 03:00:19,163 | root | INFO | GET: https://news.yahoo.co.jp/topics//domestic/?page=3
# 2020-09-18 03:00:19,164 | root | INFO | STATUS: 200
# 2020-09-18 03:00:19,207 | root | INFO | Finish Scraping
# 2020-09-18 03:00:20,380 | root | INFO | GET: https://news.yahoo.co.jp/topics//world//?page=1
# 2020-09-18 03:00:20,382 | root | INFO | STATUS: 404
# 2020-09-18 03:00:20,404 | root | INFO | Finish Scraping
# 2020-09-18 03:00:21,972 | root | INFO | GET: https://news.yahoo.co.jp/topics//world/?page=2
# 2020-09-18 03:00:21,973 | root | INFO | STATUS: 200
# 2020-09-18 03:00:22,016 | root | INFO | Finish Scraping
# 2020-09-18 03:00:22,952 | root | INFO | GET: https://news.yahoo.co.jp/topics//world/?page=3
# 2020-09-18 03:00:22,954 | root | INFO | STATUS: 404
# 2020-09-18 03:00:22,980 | root | INFO | Finish Scraping
# 2020-09-18 03:00:23,731 | root | INFO | GET: https://news.yahoo.co.jp/topics//business//?page=1
# 2020-09-18 03:00:23,732 | root | INFO | STATUS: 404
# 2020-09-18 03:00:23,756 | root | INFO | Finish Scraping
# 2020-09-18 03:00:24,555 | root | INFO | GET: https://news.yahoo.co.jp/topics//business/?page=2
# 2020-09-18 03:00:24,556 | root | INFO | STATUS: 200
# 2020-09-18 03:00:24,598 | root | INFO | Finish Scraping
# 2020-09-18 03:00:25,848 | root | INFO | GET: https://news.yahoo.co.jp/topics//business/?page=3
# 2020-09-18 03:00:25,849 | root | INFO | STATUS: 200
# 2020-09-18 03:00:25,887 | root | INFO | Finish Scraping
# 2020-09-18 03:00:27,131 | root | INFO | GET: https://news.yahoo.co.jp/topics//entertainment//?page=1
# 2020-09-18 03:00:27,132 | root | INFO | STATUS: 404
# 2020-09-18 03:00:27,154 | root | INFO | Finish Scraping
# 2020-09-18 03:00:28,406 | root | INFO | GET: https://news.yahoo.co.jp/topics//entertainment/?page=2
# 2020-09-18 03:00:28,408 | root | INFO | STATUS: 200
# 2020-09-18 03:00:28,450 | root | INFO | Finish Scraping
# 2020-09-18 03:00:29,582 | root | INFO | GET: https://news.yahoo.co.jp/topics//entertainment/?page=3
# 2020-09-18 03:00:29,583 | root | INFO | STATUS: 200
# 2020-09-18 03:00:29,620 | root | INFO | Finish Scraping
# 2020-09-18 03:00:30,372 | root | INFO | GET: https://news.yahoo.co.jp/topics//sports//?page=1
# 2020-09-18 03:00:30,373 | root | INFO | STATUS: 404
# 2020-09-18 03:00:30,405 | root | INFO | Finish Scraping
# 2020-09-18 03:00:31,290 | root | INFO | GET: https://news.yahoo.co.jp/topics//sports/?page=2
# 2020-09-18 03:00:31,291 | root | INFO | STATUS: 200
# 2020-09-18 03:00:31,332 | root | INFO | Finish Scraping
# 2020-09-18 03:00:32,163 | root | INFO | GET: https://news.yahoo.co.jp/topics//sports/?page=3
# 2020-09-18 03:00:32,164 | root | INFO | STATUS: 200
# 2020-09-18 03:00:32,203 | root | INFO | Finish Scraping
# 2020-09-18 03:00:33,486 | root | INFO | GET: https://news.yahoo.co.jp/topics//it//?page=1
# 2020-09-18 03:00:33,487 | root | INFO | STATUS: 404
# 2020-09-18 03:00:33,509 | root | INFO | Finish Scraping
# 2020-09-18 03:00:34,891 | root | INFO | GET: https://news.yahoo.co.jp/topics//it/?page=2
# 2020-09-18 03:00:34,892 | root | INFO | STATUS: 200
# 2020-09-18 03:00:34,933 | root | INFO | Finish Scraping
# 2020-09-18 03:00:35,832 | root | INFO | GET: https://news.yahoo.co.jp/topics//it/?page=3
# 2020-09-18 03:00:35,834 | root | INFO | STATUS: 404
# 2020-09-18 03:00:35,856 | root | INFO | Finish Scraping
# 2020-09-18 03:00:36,586 | root | INFO | GET: https://news.yahoo.co.jp/topics//science//?page=1
# 2020-09-18 03:00:36,587 | root | INFO | STATUS: 404
# 2020-09-18 03:00:36,611 | root | INFO | Finish Scraping
# 2020-09-18 03:00:37,461 | root | INFO | GET: https://news.yahoo.co.jp/topics//science/?page=2
# 2020-09-18 03:00:37,464 | root | INFO | STATUS: 404
# 2020-09-18 03:00:37,489 | root | INFO | Finish Scraping
# 2020-09-18 03:00:38,272 | root | INFO | GET: https://news.yahoo.co.jp/topics//science/?page=3
# 2020-09-18 03:00:38,273 | root | INFO | STATUS: 404
# 2020-09-18 03:00:38,294 | root | INFO | Finish Scraping
# 2020-09-18 03:00:38,305 | root | INFO | No. of news200
# 2020-09-18 03:00:38,306 | root | INFO | Saved file: outputs/news_20200918_120038.csv
# 2020-09-18 03:00:38,308 | root | INFO | Logs file: logs/logfile_ws01_20200918.log

# %% [markdown]
# ## Code Detail

# %%
import os
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin
from datetime import datetime, timedelta, timezone

# %%
print('Requests version: ' + str(requests.__version__))
print('BeautifulSoup version: ' + str(bs4.__version__))
print('Pandas version: ' + str(pd.__version__))
# Out:
# Requests version: 2.23.0
# BeautifulSoup version: 4.6.3
# Pandas version: 1.0.5

# %%
home_url = "https://news.yahoo.co.jp/topics/"
topics = ['domestic', 'world', 'business', 'entertainment', 'sports', 'it', 'science', 'life']
url = home_url + topics[0]
print(url)

result = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])

df = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])
# Out:
# https://news.yahoo.co.jp/topics/domestic

# %%
res = requests.get(url)  # GET Method

# %%
res.status_code # 200 is OK, 404 is Not Found
# Out:
# 200

# %%
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><style data-styled="hhHMib caYBIl fBoovI hrsGqt kTquGp cJCziL gbmduU iGMjVf fMXKmz hwtFYB bwGPsp hfRFuC bTYDKD kvwTrF kFPTQD bBCYMr hADcb diHdpL hTnmGq idEeWB bFwKkL cVzJtw hMTNII dqxkxN bCcYTo cLNZxe kKixPU gbhVmH dmEfuR hMfiGT heWWRw opOqM kXtmHq hysxHl FNDWI jLYrqT bAVKwr edZkLj inFCXz bsqfXi fXIPpx cDRFeV guTjdM eUGvfL drgvOR iGoaTi dxTGnO eBZCfC jdcIyw gWHgoh NsOhg kgGXsR OGGDU dIQmNx bdhnUx fDXrsq fntzuT eoArno kumZQI dtRHnw ldMbOW kqlTUJ gGajIV cfvFYw kOlGXS fLGZkA szsjR lnTtye gmHBwa eJMNfm jdrmnJ bRitLj eWSvDV gfJHwq hIqrOe kkoNzJ dyRSXy jECwIC iZqefY kNTYQW cYMW jfAc Qqjob ckRCrN fNSuaT kHMGun fuCSrA jAttih itcads fCcCxm jLrfAI lgBTZu gkfLJm iYZoRH jYWwiL bNjTRx hkTKeE dLBfFP kbTkLI kZGhxn gEeJGj clzMMM hqOEtE iKDLxT dmgHYf looPpP bfjcMb dvjCKo cLCgKw eCrouM jqaoCL cIOpBZ hLwNsk cFuWMT jogblL kwPRlN cEiLGJ lniAdT efeSg kCCOMK ghqeys iRWeuI hFJZos cdsyFG htGsYY dSuDFJ djSCat gGLQLz cCuJGn gRtRsy wnmnh eGTRSy VFRgJ gPjQJW gAqjLT hFCzaq gahaYI ecLMZv ZLVCy dgtlxd iWIUfE bLTBpS hxMCXm kYIuOH" data-styled-streamed="true" data-styled-version="4.4.1">
# /* sc-component-id: sc-frpTsy */
# .hhHMib{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:0 15px;}
# /* sc-component-id: sc-jbxdUx */
# .caYBIl{position:absolute;}
# /* sc-component-id: sc-bMuqKn */
# .fBoovI{display:block;width:108px;height:44px;background-image:url(https://s.yimg.jp/c/logo/s/2.0/news_r_22_2x.png);background-size:108px 22px;background-repeat:no-repeat;background-position:right 50%;text-indent:-9999px;overflow:hidden;white-space:nowrap;}
# /* sc-component-id: sc-irsooP */
# .hrsGqt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: sc-kVfTjK */
# .kTquGp{margin-left:10px;font-size:1.4rem;}
# /* sc-component-id: sc-CTzJj */
# .cJCziL{color:#006ccc;}
# /* sc-component-id: sc-bripbU */
# .gbmduU{display:none;width:calc(100% - 16px * 2);margin:auto;padding:3px 0;background-color:#1a75ff;color:#fff;border-radius:4px;text-align:center;font-size:14px;} .gbmduU.amp-visible{visibility:visible;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: sc-cFlMtL */
# .iGMjVf{border-top:1px solid #d5dae1;}.fMXKmz{border-top:1px solid #d5dae1;border-top:8px solid #e5eaee;}
# /* sc-component-id: sc-bchHHi */
# .hwtFYB{background:#fff;}
# /* sc-component-id: sc-ewTrYR */
# .bwGPsp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;max-width:450px;margin-right:auto;margin-left:auto;}
# /* sc-component-id: sc-bEGMXy */
# .hfRFuC{-webkit-order:98;-ms-flex-order:98;order:98;width:100%;background:#fff;font-size:1.2rem;color:#949494;text-align:right;line-height:1.6;padding:16px 16px 12px;}
# /* sc-component-id: sc-gBGeja */
# .bTYDKD{display:inline;font-weight:bold;margin-right:8px;}
# /* sc-component-id: sc-dLHtUl */
# .kvwTrF{background:#fff;}
# /* sc-component-id: sc-dmXgXv */
# .kFPTQD{position:relative;}
# /* sc-component-id: sc-cqOjgt */
# .bBCYMr{display:block;}
# /* sc-component-id: sc-jTdKgc */
# .hADcb{display:block;width:100%;padding-bottom:150px;padding-bottom:calc(100% * (93 / 225));} .hADcb::before{content:'';display:block;position:absolute;top:0;bottom:0;left:0;right:0;opacity:0.7;z-index:1;background-image:linear-gradient( to bottom, rgba(0,0,0,0), rgba(0,0,0,0) 40%, rgba(0,0,0,0.1) 80%, rgba(0,0,0,0.3) );z-index:1;}
# /* sc-component-id: sc-hGKTXy */
# .diHdpL{position:absolute;top:50%;left:50%;-webkit-transform:translateY(-50%) translateX(-50%);-ms-transform:translateY(-50%) translateX(-50%);transform:translateY(-50%) translateX(-50%);width:100%;max-height:calc(450px * 52 / 100);}
# /* sc-component-id: sc-kFvBWJ */
# .hTnmGq{position:absolute;bottom:8px;right:8px;z-index:100;text-shadow:0 1px 3px rgba(0,0,0,0.5);color:#fff;}
# /* sc-component-id: sc-ikTlrC */
# .idEeWB{font-size:1.2rem;}
# /* sc-component-id: sc-cBqwIa */
# .bFwKkL{position:relative;top:3px;}
# /* sc-component-id: sc-bnOsYM */
# .cVzJtw{padding:12px 16px 0;}
# /* sc-component-id: sc-bOFpUc */
# .hMTNII{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;} .hMTNII a{display:block;width:100%;}
# /* sc-component-id: sc-AhSAr */
# .dqxkxN{font-size:1.8rem;font-weight:bold;line-height:1.4;}
# /* sc-component-id: sc-kqqoiJ */
# .bCcYTo{max-width:180px;margin-right:auto;margin-top:8px;font-size:1.4rem;line-height:18px;color:#949494;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;}
# /* sc-component-id: sc-bnQDJF */
# .cLNZxe{margin-top:8px;font-size:1.6rem;font-weight:bold;}
# /* sc-component-id: sc-gnDgBH */
# .kKixPU{display:block;width:100%;color:#3474ce;color:#3474ce;} .kKixPU svg{fill:#3474ce;}
# /* sc-component-id: sc-jggjFL */
# .gbhVmH{position:relative;top:4px;}
# /* sc-component-id: sc-lgsYow */
# .dmEfuR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin-top:8px;}
# /* sc-component-id: sc-dTOuAs */
# .hMfiGT{margin-left:8px;}
# /* sc-component-id: sc-dDojKJ */
# .heWWRw{display:block;}
# /* sc-component-id: sc-eNhIyc */
# .opOqM{display:block;width:24px;height:24px;}
# /* sc-component-id: sc-cVVlNl */
# .kXtmHq{padding-top:8px;line-height:1.6;white-space:pre-line;}
# /* sc-component-id: sc-fQrEfc */
# .hysxHl{text-align:center;margin-top:12px;}
# /* sc-component-id: sc-cPUNzw */
# .FNDWI{display:inline-block;min-width:152px;padding:8px 32px;border:1px #1a75ff solid;border-radius:4px;color:#1a75ff;font-size:1.4rem;font-weight:700;}
# /* sc-component-id: sc-gBIyv */
# .jLYrqT{width:100%;background:#fff;padding:16px 16px 0;}
# /* sc-component-id: sc-eWIzRM */
# .bAVKwr{background-image:url('https://s.yimg.jp/images/jpnews/v2/all/images/pickupPoint_kensaku.svg');background-size:auto;background-repeat:no-repeat;position:relative;height:48px;width:198px;}
# /* sc-component-id: sc-bDOcnW */
# .edZkLj{display:inline-block;position:absolute;bottom:-1px;left:83px;width:114px;height:26px;font-size:1.3rem;font-weight:bold;text-align:center;color:#fff;line-height:26px;}
# /* sc-component-id: sc-eFTCDY */
# .inFCXz{margin-top:16px;border-left:2px solid #e5eaee;} .inFCXz:first-child{margin-top:12px;}
# /* sc-component-id: sc-fwNAQS */
# .bsqfXi{padding-left:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#949494;}
# /* sc-component-id: sc-fXUpvm */
# .fXIPpx{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;}
# /* sc-component-id: sc-hLYIQQ */
# .cDRFeV{font-size:1.6rem;font-weight:bold;line-height:1.3;color:#333;} .cDRFeV:hover{-webkit-text-decoration:none;text-decoration:none;}
# /* sc-component-id: sc-cROsgo */
# .guTjdM{padding-top:4px;font-size:1.1rem;}
# /* sc-component-id: sc-gsVOdK */
# .eUGvfL::before{content:' ';}
# /* sc-component-id: sc-fXchrD */
# .drgvOR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;margin-left:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:60px;height:60px;background-repeat:no-repeat;background-size:contain;background-position:center;background-image:url(https://amd.c.yimg.jp/im_sigglDnu_McE8u6t2cTLCcGmug---x264-y264-xc692-yc0-wc1466-hc1466-q90-exp3h-pril/amd/20200704-00000150-kyodonews-000-3-view.jpg);}
# /* sc-component-id: sc-jCodtT */
# .iGoaTi{background:#fff;border-top:solid 8px #e5eaee;}
# /* sc-component-id: sc-chYKBT */
# .dxTGnO{padding:12px 8px 0;}
# /* sc-component-id: sc-bRbqnn */
# .eBZCfC{padding-bottom:4px;border-bottom:1px solid #d5dae1;font-size:1.4rem;font-weight:700;line-height:21px;}
# /* sc-component-id: sc-mWPeY */
# .jdcIyw{padding:8px;}
# /* sc-component-id: sc-inlrYM */
# .gWHgoh:not(:first-child) .sc-fZNsvg{position:relative;} .gWHgoh:not(:first-child) .sc-fZNsvg::before{content:'';display:block;left:8px;right:4px;height:1px;background-color:#e5eaee;position:absolute;top:-2px;}
# /* sc-component-id: sc-dTSiUb */
# .NsOhg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;padding:2px 0;} .NsOhg:visited{color:#949494;}
# /* sc-component-id: sc-beKmYL */
# .kgGXsR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;width:52px;height:52px;position:relative;background-color:#efefef;} .kgGXsR::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:52px;height:52px;border:solid 1px rgba(0,0,0,0.06);}
# /* sc-component-id: sc-ilGAqu */
# .OGGDU{max-width:52px;max-height:52px;}
# /* sc-component-id: sc-fZNsvg */
# .dIQmNx{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-left:8px;}
# /* sc-component-id: sc-kaCJFH */
# .bdhnUx{margin-top:2px;font-weight:bold;font-size:1.6rem;}
# /* sc-component-id: sc-eQvJSV */
# .fDXrsq{color:#949494;font-size:1.1rem;vertical-align:middle;}
# /* sc-component-id: sc-OJyzl */
# .fntzuT{padding:8px 0 4px;background:#fff;text-align:center;}
# /* sc-component-id: sc-beROAQ */
# .eoArno{text-align:center;background:#fff;padding:16px 0;border-top:solid 8px #e5eaee;}
# /* sc-component-id: sc-iWdsyN */
# .kumZQI{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:8px 32px;border:solid 1px #bbb;background-color:#fff;border-radius:4px;font-size:1.4rem;color:#444;font-weight:bold;}
# /* sc-component-id: sc-eYTUqP */
# .dtRHnw{margin:0 4px 0 0;}
# /* sc-component-id: sc-iupvsZ */
# .ldMbOW{font-size:1.2rem;}
# /* sc-component-id: sc-gKGeJo */
# .kqlTUJ{display:block;position:relative;-webkit-tap-highlight-color:rgba(237,239,241,0.4);} .kqlTUJ::before{position:absolute;top:50%;right:12px;width:8px;height:8px;border-top:1px solid #949494;border-right:1px solid #949494;-webkit-transform:rotate(45deg) translateY(-50%);-ms-transform:rotate(45deg) translateY(-50%);transform:rotate(45deg) translateY(-50%);content:'';} .kqlTUJ .sc-iAjrqK{padding-right:20px;} .kqlTUJ .sc-dAAzKL{font-weight:bold;}
# /* sc-component-id: sc-iAjrqK */
# .gGajIV{padding:5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-bottom:1px solid #d5dae1;background:#fff;} .gGajIV:visited .sc-dAAzKL{color:#949494;}
# /* sc-component-id: sc-hpAzQi */
# .cfvFYw{display:block;width:40px;height:40px;background:url(https://s.yimg.jp/images/jpnews/cre/new-normal/banner/spot/ico_80_80.png) no-repeat left center/contain;margin-right:5px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}
# /* sc-component-id: sc-iKIEpe */
# .kOlGXS{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-dAAzKL */
# .fLGZkA{color:#333;font-size:1.4rem;}
# /* sc-component-id: sc-fWoLFK */
# .szsjR{color:#949494;font-size:1.2rem;}
# /* sc-component-id: sc-bXtxjY */
# .lnTtye{background:#fff;border-top:solid 8px #e5eaee;}
# /* sc-component-id: sc-dyKSPo */
# .gmHBwa{padding:12px 8px 0;}
# /* sc-component-id: sc-kVyEtE */
# .eJMNfm{padding-bottom:4px;border-bottom:1px solid #d5dae1;font-size:1.4rem;font-weight:bold;line-height:21px;}
# /* sc-component-id: sc-lewbHj */
# .jdrmnJ{padding:8px;}
# /* sc-component-id: sc-dJJlpf */
# .bRitLj{padding:4px 0;} .bRitLj:first-of-type{padding-top:0;} .bRitLj:last-of-type{padding-bottom:0;} .bRitLj:last-of-type .sc-gXPbch::before{content:none;}
# /* sc-component-id: sc-hBAczQ */
# .eWSvDV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}
# /* sc-component-id: sc-bhVptL */
# .gfJHwq{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://mitsumame-pctr.c.yimg.jp/OF3pa1aWCcRom2JxRnlEAWGi7iC77EBtrM1LGweZF9Ku7Dd4L0jkd8QlAtB6SlrYdQFvZG8oQDEFT0aMUYkarhTaXeuPxKVFprnbRD4cN64VvjoYmgcWSyYA3u5CNcLuMdIb31kY95fjA2D2Tis3xDxy9XFamaPaTFZUJGmToac=);background-color:#efefef;} .gfJHwq::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.hIqrOe{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://mitsumame-pctr.c.yimg.jp/OF3pa1aWCcRom2JxRnlEAWGi7iC77EBtrM1LGweZF9LfCh0HALru7_7S2lr7SPmtzuZDA3nNooBw1yGlewHZiLbqS_oX4VaUwrRlyxZXoL-uw9U0rqf9fbsY5gj5y37XLIPFMOazjUu48DdvnlglDg==);background-color:#efefef;} .hIqrOe::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.kkoNzJ{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://mitsumame-pctr.c.yimg.jp/OF3pa1aWCcRom2JxRnlEAWGi7iC77EBtrM1LGweZF9Ipjk_xtrLrNgqpGJSrboVMjkyZMyRlsbVSD3Jr0cNir78_C4T_nsHCySEea3UgkYgHJ6YJo4W5qyrt1N2UWNnYIvnjVdwaPsWqGCVEmwyGhjdGNYQtGleXZasHokqKJOI=);background-color:#efefef;} .kkoNzJ::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.dyRSXy{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://amd.c.yimg.jp/im_siggi4oumu3B_NtnpeJi5v_prg---x264-y264-q90-exp3h-pril/amd/cate_image/ent.jpg);background-color:#efefef;} .dyRSXy::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.jECwIC{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://mitsumame-pctr.c.yimg.jp/OF3pa1aWCcRom2JxRnlEAWGi7iC77EBtrM1LGweZF9K7Yj88V3NLokOmC8SjIf0Piqe-weMkcwi4pWpYq3TLCs4un-5S1YqkKqSUzK1EGm8=);background-color:#000;} .jECwIC::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.iZqefY{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://mitsumame-pctr.c.yimg.jp/OF3pa1aWCcRom2JxRnlEAWGi7iC77EBtrM1LGweZF9KJiG9ELZzgFipwA2_5EN8N5XcdTWuV_GGCSpPhAZjFGk2MSjfJ7fONDOwAYIWHYeMqqKjQ7zCyEj3Xn7UKJxH5KIrj9IJCYQZSujU7bCBeam7lY_-l0CbLg4N8aqxzLHM=);background-color:#efefef;} .iZqefY::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.kNTYQW{margin-right:12px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:96px;height:96px;background-size:contain;background-repeat:no-repeat;background-position:center;position:relative;background-image:url(https://mitsumame-pctr.c.yimg.jp/OF3pa1aWCcRom2JxRnlEAWGi7iC77EBtrM1LGweZF9KetsdO5P94mOhZCIeZaNvTrCa50Een7QJDOOy5CcKkA8uuaY8f3qRQkpCjyerqEO6cR06GfelZigdyupLy2psCTEq3WWVBNjwZOEQiVGifow==);background-color:#efefef;} .kNTYQW::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;he ...
# /* sc-component-id: sc-gXPbch */
# .cCuJGn{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;position:relative;} .cCuJGn::before{content:'';display:block;left:0;right:4px;height:1px;background-color:#e5eaee;position:absolute;bottom:-4px;}
# /* sc-component-id: sc-jvjKQy */
# .gRtRsy{display:-webkit-box;-webkit-box-orient:vertical;overflow:hidden;-webkit-line-clamp:3;font-weight:bold;font-size:1.6rem;line-height:1.4;word-break:break-all;}
# /* sc-component-id: sc-jgjKxb */
# .wnmnh{margin:8px 0 0 -8px;color:#949494;line-height:1.1;font-size:0;}
# /* sc-component-id: sc-cTnXXA */
# .eGTRSy{display:inline-block;margin-left:8px;font-size:1.1rem;}
# /* sc-component-id: sc-fdcRnX */
# .VFRgJ{display:inline-block;margin-left:8px;font-size:1.1rem;}
# /* sc-component-id: sc-goBNrf */
# .gPjQJW{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:absolute;right:0;bottom:0;padding:calc(4px / 2) calc(4px) calc(4px / 2) calc(4px + 2px);color:#fff;font-family:Helvetica;font-size:11px;line-height:1;background-color:rgba(0,0,0,0.7);}
# /* sc-component-id: sc-bzlMTP */
# .gAqjLT{margin:0 -2px 0 -2px;}
# /* sc-component-id: sc-fxiptW */
# .hFCzaq{margin-left:4px;}
# /* sc-component-id: sc-cGrIXu */
# .gahaYI{padding:4px 0;} .gahaYI:first-of-type{padding-top:0;} .gahaYI:last-of-type{padding-bottom:0;} .gahaYI:last-of-type .sc-gXPbch::before{content:none;} .gahaYI .sc-hBAczQ{display:block;padding:4px 0;} .gahaYI .sc-bhVptL{width:100%;height:calc((100vw - 16px) * 52 / 100);max-height:300px;} .gahaYI .sc-jvjKQy{margin-top:4px;} .gahaYI .sc-jgjKxb{margin:4px 0 4px -8px;}
# /* sc-component-id: sc-kicAms */
# .ecLMZv{font-size:1.4rem;line-height:1;text-align:center;} .ecLMZv::before{content:'';display:block;width:100%;height:8px;background-color:#e5eaee;}
# /* sc-component-id: sc-hkJSjt */
# .ZLVCy{padding:13px 10px 15px 10px;border-top:3px solid #d5dae1;background:#efefef;}
# /* sc-component-id: sc-gIhonS */
# .dgtlxd{margin-bottom:10px;} .dgtlxd .sc-eePzDA:not(:last-child)::after{content:' | ';}
# /* sc-component-id: sc-eePzDA */
# .iWIUfE{display:inline;}
# /* sc-component-id: sc-dUZuEM */
# .bLTBpS{color:#006ccc;} .bLTBpS:visited{color:#639;}
# /* sc-component-id: sc-kdlMoT */
# .hxMCXm{margin-bottom:8px;font-size:1.2rem;} .hxMCXm .sc-eePzDA:not(:last-child)::after{content:' - ';}
# /* sc-component-id: sc-etRtft */
# .kYIuOH{display:block;font-size:1.2rem;line-height:1.6;}</style><style data-styled="gbTit TEnve eXTYfg gxlsFv jXkxHL gUNSGz fnvnXv fGGTLx bWoSBt fieSHS cLLkqm cEbcbj" data-styled-streamed="true" data-styled-version="4.4.1">
# /* sc-component-id: sc-gipzik */
# .gbTit{position:relative;}
# /* sc-component-id: sc-csuQGl */
# .TEnve{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:316px;margin:8px 12px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-Rmtcm */
# .eXTYfg{position:relative;border:1px solid #bbb;border-right:none;border-radius:3px 0 0 3px;background-color:#fff;} .eXTYfg:after{display:block;content:'';position:absolute;top:50%;right:0;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);border-right:1px solid #bbb;height:12px;} .eXTYfg::-webkit-input-placeholder{color:#aaaaaa;} .eXTYfg::-moz-placeholder{color:#aaaaaa;} .eXTYfg:-ms-input-placeholder{color:#aaaaaa;} .eXTYfg::placeholder{color:#aaaaaa;}
# /* sc-component-id: sc-bRBYWo */
# .gxlsFv{width:282px;height:26px;padding-left:4px;font-size:1.2rem;line-height:26px;}
# /* sc-component-id: sc-hzDkRC */
# .jXkxHL{background-color:#fff;border:1px solid #bbb;border-left:none;border-radius:0 3px 3px 0;}
# /* sc-component-id: sc-jhAzac */
# .gUNSGz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:26px;padding:0 8px;cursor:pointer;}
# /* sc-component-id: sc-fBuWsC */
# .fnvnXv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#efefef;height:60px;width:60px;} .fnvnXv::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.fGGTLx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#000;height:60px;width:60px;} .fGGTLx::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}
# /* sc-component-id: sc-fMiknA */
# .bWoSBt{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;max-height:calc(60px + 1px);max-width:calc(60px + 1px);}
# /* sc-component-id: sc-dVhcbM */
# .fieSHS{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:absolute;right:0;bottom:0;padding:calc(4px / 2) calc(4px) calc(4px / 2) calc(4px + 2px);color:#fff;font-family:Helvetica;font-size:11px;line-height:1;background-color:rgba(0,0,0,0.7);}
# /* sc-component-id: sc-fAjcbJ */
# .cLLkqm{margin:0 -2px 0 -2px;}
# /* sc-component-id: sc-eqIVtm */
# .cEbcbj{margin-left:4px;}</style><title>国内トピックス一覧 - Yahoo!ニュース</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=970" name="viewport"/><meta content="text/css" http-equiv="Content-Style-Type"/><meta content="text/javascript" http-equiv="Content-Script-Type"/><meta content="国内トピックスを新着順にお届け。Yahoo!ニュースでは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事などを掲載しています。" name="description"/><meta content="noarchive, max-image-preview:large" name="robots"/><meta content="telephone=no" name="format-detection"/><meta content="dVyTbsDzUrUAjCE1aCH9hKwZ8sOsCsvi2uhuBvasrp8" name="google-site-verification"/><meta content="Yahoo!ニュース" property="og:site_name"/><meta content="https://s.yimg.jp/images/jpnews/cre/common/all/images/fbico_ogp_1200x630.png" property="og:image"/><meta content="国内トピックスを新着順にお届け。Yahoo!ニュースでは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事などを掲載しています。" property="og:description"/><meta content="国内トピックス一覧 - Yahoo!ニュース" property="og:title"/><meta content="website" property="og:type"/><meta content="https://news.yahoo.co.jp/topics/domestic" property="og:url"/><meta content="ja_JP" property="og:locale"/><meta content="https://s.yimg.jp/c/icon/s/bsc/2.0/news144.png" name="msapplication-TileImage"/><meta content="#FFFFFF" name="msapplication-TileColor"/><meta content="276725822409153" property="fb:app_id"/><meta content="国内トピックスを新着順にお届け。Yahoo!ニュースでは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事などを掲載しています。" name="twitter:description"/><meta content="https://s.yimg.jp/images/jpnews/cre/common/all/images/fbico_ogp_1200x630.png" name="twitter:image"/><meta content="jp" name="twitter:app:country"/><meta content="summary_large_image" name="twitter:card"/><meta content="国内トピックス一覧 - Yahoo!ニュース" name="twitter:title"/><meta content="@YahooNewsTopics" name="twitter:site"/><meta content="Yahoo!ニュース" name="twitter:app:name:iphone"/><meta content="407906756" name="twitter:app:id:iphone"/><meta content="yjnews://l/top/" name="twitter:app:url:iphone"/><meta content="Yahoo!ニュース" name="twitter:app:name:googleplay"/><meta content="jp.co.yahoo.android.news" name="twitter:app:id:googleplay"/><meta content="yjnews://l/top/" name="twitter:app:url:googleplay"/><meta content="Yahoo!ニュース" property="al:ios:app_name"/><meta content="407906756" property="al:ios:app_store_id"/><meta content="yjnews://l/top/" property="al:ios:url"/><meta content="Yahoo!ニュース" property="al:android:app_name"/><meta content="jp.co.yahoo.android.news" property="al:android:package"/><link href="https://s.yimg.jp/c/icon/s/bsc/2.0/news120.png" rel="apple-touch-icon-precomposed"/><link href="https://s.yimg.jp/c/icon/s/bsc/2.0/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link href="https://s.yimg.jp/images/jpnews/v2/pc/css/topicsList-4fe2941d8b56f2f85846.css" rel="stylesheet"/><script></script>
# <!-- basic-MHCSS -->
# <!-- mhcss -->
# <link href="https://s.yimg.jp/yui/jp/mh/pc/1.5.6/css/std.css" media="all" rel="stylesheet" type="text/css"/>
# <!-- /mhcss -->
# <script></script></head><body class=""><div class="tracked_mods" id="wrapper"><header id="yjnHeader"><h1>Yahoo!ニュース</h1><div id="yjnEmg"><!-- basic-MH-logout -->
# <!-- mhd -->
# <div id="msthd">
# <div>
# <div id="msthdtp">
# <div id="mhd_uhd_pc"></div>
# <div id="msthdsb">
# <div class="msthdLink">
# <ul>
# <li class="msthdLinkYtop"><a data-redirectadclick="" data-ylk="slk:h_ytop;pos:0" href="https://www.yahoo.co.jp/" id="msthdYtop">Yahoo! JAPAN</a></li>
# <!-- mhhl -->
# <li class="msthdLinkHelp"><a data-redirectadclick="" data-ylk="slk:h_hlp;pos:0" href="https://www.yahoo-help.jp/app/home/service/news/" id="msthdHelp">ヘルプ</a></li>
# <!-- /mhhl -->
# </ul>
# </div>
# <div id="msthdsrch">
# <form action="https://search.yahoo.co.jp/search" data-redirectadclick="" name="p">
# <p id="msthdsrchBox">
# <label class="offLeft" for="msthdsbox" id="msthdslb" title="キーワード：">キーワード：</label>
# <input id="msthdsbox" name="p" placeholder="ウェブ検索" type="text" value=""/>
# <button id="msthdsbt" title="検索" type="submit">検索</button>
# <input id="msthdei" name="ei" type="hidden" value="UTF-8"/>
# <input name="fr" type="hidden" value="ush"/>
# </p>
# </form>
# </div>
# </div>
# </div>
# <!-- mhlg -->
# <div class="logo">
# <a data-redirectadclick="" data-ylk="slk:h_srvtop;pos:0" href="https://news.yahoo.co.jp/" id="msthdLogo">
# <img alt="Yahoo!ニュース" height="34" src="https://s.yimg.jp/c/logo/f/2.0/news_r_34_2x.png" width="206"/>
# </a>
# </div>
# <!-- /mhlg -->
# <!-- mhli_logout -->
# <div class="msthdtxt">
# <p>IDでもっと便利に<a class="b" data-redirectadclick="" data-ylk="slk:h_regyid;pos:0" href="https://account.edit.yahoo.co.jp/registration?.intl=jp&amp;.done=https%3A%2F%2Fnews.yahoo.co.jp%2Ftopics%2Fdomestic&amp;.src=news" id="msthdReg">新規取得</a></p>
# <p><a class="b" data-redirectadclick="" data-ylk="slk:h_login;pos:0" href="https://login.yahoo.co.jp/config/login?.src=news&amp;lg=jp&amp;.intl=jp&amp;.done=https%3A%2F%2Fnews.yahoo.co.jp%2Ftopics%2Fdomestic" id="msthdLogin">ログイン</a><span id="mhd_text_pc"></span></p>
# </div>
# <!-- /mhli_logout -->
# </div>
# </div>
# <script src="https://s.yimg.jp/images/security/pf/pcore-1.0.2.min.js" type="text/javascript"></script>
# <script src="https://s.yimg.jp/images/security/pf/yjsecure.js" type="text/javascript"></script>
# <script src="https://s.yimg.jp/images/mempf/mt_pc_mhd.js" type="text/javascript"></script>
# <script type="text/javascript">
# window.msthdPromo = function() {
#   YAHOO.JP.msthd.Promo.init();
# };
# </script>
# <script type="text/javascript">
#   (function(d,t){var s=d.getElementsByTagName(t)[0],n=d.createElement(t);n.id='msthdScript';n.src='https://s.yimg.jp/yui/jp/mh/pc/1.8.13/js/std-min.js';n.setAttribute('data-s','');n.setAttribute('data-tm','');s.parentNode.insertBefore(n,s);}(document,'script'));
# </script>
# <!-- /mhd -->
# <div class="yjnEmg_emg3" data-reactroot=""></div><div class="yjnEmg_emg2" data-reactroot=""></div><div class="yjnEmg_emg1" data-reactroot=""></div></div><nav id="yjnHeader_nav"><div id="gnavi"><div class="yjnHeader_tools"><div id="searchBoxWrap-header"><form action="/search" class="searchNewsrm" method="get"><div class="sc-gipzik gbTit"><div class="sc-csuQGl TEnve"><div class="sc-Rmtcm eXTYfg"><input autocomplete="off" class="sc-bRBYWo gxlsFv" name="p" placeholder="キーワードを入力" type="text" value=""/><input name="ei" type="hidden" value="utf-8"/></div><div class="sc-hzDkRC jXkxHL"><button class="sc-jhAzac gUNSGz" type="submit" value="検索"><svg fill="#444444" height="18" viewbox="0 0 48 48" width="18"><path d="M21 32c-6.075 0-11-4.925-11-11s4.925-11 11-11 11 4.925 11 11-4.925 11-11 11m20.414 6.586l-8.499-8.499A14.919 14.919 0 0036 21c0-8.284-6.716-15-15-15-8.284 0-15 6.716-15 15 0 8.284 6.716 15 15 15a14.91 14.91 0 009.086-3.085l8.5 8.499a2 2 0 102.828-2.828" fill-rule="evenodd"></path></svg></button></div></div></div></form></div><ul class="yjnHeader_tools_person"><li class="yjnheader_mypage "><a data-ylk="rsec:gnavi;slk:profnm;" href="https://news.yahoo.co.jp/profile/login" rel="nofollow">ユーザーページ</a></li><li class="yjnheader_purchase "><a data-ylk="rsec:gnavi;slk:pur;" href="/purchase" rel="nofollow">購入履歴</a></li><li class="yjnHeader_setting "><a data-ylk="rsec:gnavi;slk:set;" href="https://news.yahoo.co.jp/profile/settings/" rel="nofollow">設定</a></li></ul></div><ul class="yjnHeader_nav_main"><li class="current "><a data-ylk="rsec:gnavi;slk:hl;" href="/">トップ</a></li><li class=""><a data-ylk="rsec:gnavi;slk:fl;" href="/flash">速報</a></li><li class=""><a data-ylk="rsec:gnavi;slk:mv;" href="/live">ライブ</a></li><li class=""><a data-ylk="rsec:gnavi;slk:by;" href="https://news.yahoo.co.jp/byline/">個人</a></li><li class=""><a data-ylk="rsec:gnavi;slk:fea;" href="https://news.yahoo.co.jp/feature">特集</a></li><li class=""><a data-ylk="rsec:gnavi;slk:poll;" href="https://news.yahoo.co.jp/polls/">みんなの意見</a></li><li class=""><a data-ylk="rsec:gnavi;slk:accrank;" href="/ranking/access/news">ランキング</a></li><li class=""><a data-ylk="rsec:gnavi;slk:paid;" href="/paidnews">有料</a></li></ul></div><div class="yjnHeader_nav_sub" id="snavi"><ul class="yjnHeader_sub_cat"><li class=""><a data-ylk="rsec:snavi;slk:maj;" href="/">主要</a></li><li class=""><a data-ylk="rsec:snavi;slk:dom;" href="/categories/domestic">国内</a></li><li class=""><a data-ylk="rsec:snavi;slk:wor;" href="/categories/world">国際</a></li><li class=""><a data-ylk="rsec:snavi;slk:bus;" href="/categories/business">経済</a></li><li class=""><a data-ylk="rsec:snavi;slk:ent;" href="/categories/entertainment">エンタメ</a></li><li class=""><a data-ylk="rsec:snavi;slk:spo;" href="/categories/sports">スポーツ</a></li><li class=""><a data-ylk="rsec:snavi;slk:it;" href="/categories/it">IT</a></li><li class=""><a data-ylk="rsec:snavi;slk:sci;" href="/categories/science">科学</a></li><li class=""><a data-ylk="rsec:snavi;slk:lif;" href="/categories/life">ライフ</a></li><li class=""><a data-ylk="rsec:snavi;slk:loc;" href="/categories/local">地域</a></li></ul><ul class="yjnHeader_sub_arc"><li class="current "><a data-ylk="rsec:snavi;slk:tpc_list;" href="/topics/top-picks">トピックス一覧</a></li></ul></div></nav></header><main class="" id="contents"><div id="yjnMain"><div class="contentsWrap" id="contentsWrap"><noscript><div class="information information-warning"><p class="information_text">現在JavaScriptが無効になっています。Yahoo!ニュースのすべての機能を利用するためには、JavaScriptの設定を有効にしてください。</p><a class="information_link" href="https://www.yahoo-help.jp/app/noscript">JavaScriptの設定を変更する方法はこちら</a></div></noscript><header class="title"><div class="title_inner"><div class="titleMain"><h2 class="titleMain_main">トピックス一覧</h2></div><ul class="titleLink"><li class="titleLink_item "><a data-ylk="rsec:tpc_list;slk:link;pos:1;" href="/topics">全カテゴリ</a></li><li class="titleLink_item titleLink_item-current"><a data-ylk="rsec:tpc_list;slk:link;pos:2;" href="/topics/top-picks" ...
#           window.ualcmds = window.ualcmds || [];
#           window.ual = window.ual || function() {
#             ualcmds.push(arguments);
#           };
#
#           ual('config', 'token', '5ae7ece4-3b93-4890-8f24-ce16ddd756ed');
#           ual('hit', 'pageview', {
#             service: 'news',
#             opttype: 'pc',
#
#
#             hierarchy_id: '2080282684',
#             mtestid:'mfn_3895='
#           });
#         </script><script src="https://s.yimg.jp/images/jpnews/v2/pc/js/categorizedTopicsList-543e97742ca9d443fc5d.js" type="text/javascript"></script></body></html>

# %%
titles = soup.find_all('div', {'class': 'newsFeed_item_title'})
datetimes = soup.find_all('time', {'class': 'newsFeed_item_date'})

# %%
print(len(titles))
titles[0:3]
# Out:
# 25
# [<div class="newsFeed_item_title">北陸や北海道 強い雨に注意</div>,
#  <div class="newsFeed_item_title">二階氏温情 石破派複雑な表情</div>,
#  <div class="newsFeed_item_title">「官邸主導」強固に 官僚恐々</div>]

# %%
df = pd.DataFrame(list(zip(titles, datetimes)), columns =['titles', 'datetimes']) 

spec_chars = ['<div class="newsFeed_item_title">', '</div>']
for char in spec_chars:
  df['titles'] = df['titles'].astype(str).str.replace(char, ' ')

spec_chars = ['<time class="newsFeed_item_date">', '</time>']
for char in spec_chars:
  df['datetimes'] = df['datetimes'].astype(str).str.replace(char, ' ')

df['topics'] = topics[3]

# %%
result = pd.concat([result, df])

# %%
len(result)
result.tail(5)
# Out:
#                  titles        datetimes    topics
# 20    ゆうちょ銀不正被害 1811万円    9/16(水) 17:18   business
# 21      ドコモ口座 過去みずほ被害か    9/16(水) 17:04   business
# 22   JR東4180億円赤字 民営化後初    9/16(水) 16:57   business
# 23   SBI証券 9864万円が不正流出    9/16(水) 16:46   business
# 24      タピオカバブル崩壊 専門店減    9/16(水) 16:15   business

# %% [markdown]
# interation 2

# %%
df = pd.DataFrame(columns=['titles', 'datetimes', 'topics'])

urlpath = topics[3] + "/" + page_no[1]
url = urljoin(home_url, urlpath)
url

res = requests.get(url)  # GET Method

soup = BeautifulSoup(res.text, 'lxml')

titles = soup.find_all('div', {'class': 'newsFeed_item_title'})
datetimes = soup.find_all('time', {'class': 'newsFeed_item_date'})

df = pd.DataFrame(list(zip(titles, datetimes)), columns =['titles', 'datetimes']) 

spec_chars = ['<div class="newsFeed_item_title">', '</div>']
for char in spec_chars:
  df['titles'] = df['titles'].astype(str).str.replace(char, ' ')

spec_chars = ['<time class="newsFeed_item_date">', '</time>']
for char in spec_chars:
  df['datetimes'] = df['datetimes'].astype(str).str.replace(char, ' ')

df['topics'] = topics[3]

result = pd.concat([result, df])

# %%
print(len(result))
result.tail(5)
# Out:
# 50
#                   titles        datetimes    topics
# 20      米航空の日本人CA 失職の恐れ    9/14(月) 12:52   business
# 21       観光政策変わる?注視する京都    9/14(月) 10:43   business
# 22       倒産「予備軍多い」年末急増?     9/14(月) 8:51   business
# 23   SBG アーム全株NVIDIAに売却     9/14(月) 8:43   business
# 24       SBG 株式の非公開化を検討     9/14(月) 8:20   business

# %% [markdown]
# save file

# %%
jst = timezone(timedelta(hours=9), 'JST')
now = datetime.now(jst).strftime("%Y%m%d_%H%M%S")
output_folder = 'outputs/'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output = output_folder + 'news_' + now + '.csv'

result.to_csv(output, index=False, encoding='utf_8_sig')
print('Save file: ' + output)
# Out:
# Save file: outputs/news_20200917_235428.csv

# %% [markdown]
# logging

# %%
import os
import logging
from datetime import datetime

def create_logging():
  """ Create logging """
  logs_folder = 'logs/'
  if not os.path.exists(logs_folder):
    os.makedirs(logs_folder)

  log_dir = logs_folder + str(datetime.now().strftime('logfile_ws02_%Y%m%d.log'))
  logging.basicConfig(filename=log_dir,
                  level=logging.INFO,
                  format='%(asctime)s | %(name)s | %(levelname)s | %(message)s')
  console = logging.StreamHandler()
  console.setLevel(logging.INFO)
  formatter = logging.Formatter('%(asctime)s | %(name)s | %(levelname)s | %(message)s')
  console.setFormatter(formatter)
  logging.getLogger('').addHandler(console)
  logging.info('Started')
  logging.info('Log file : ' + str(log_dir))
  logging.info('Python environment : ' + str(sys.version))
  logging.info('Requests version: ' + str(requests.__version__))
  logging.info('BeautifulSoup version: ' + str(bs4.__version__))
  logging.info('Pandas version: ' + str(pd.__version__))

create_logging()
# Out:
# 2020-09-18 04:08:34,780 | root | INFO | Started
# 2020-09-18 04:08:34,781 | root | INFO | Log file : logs/logfile_ws02_20200918.log
# 2020-09-18 04:08:34,784 | root | INFO | informational message.
# 2020-09-18 04:08:34,787 | root | WARNING | warning!
# 2020-09-18 04:08:34,789 | root | CRITICAL | critial!
