# %% [markdown]
# ## set.or.th

# %%
import pandas as pd

# %%
url = 'https://www.set.or.th/set/companyprofile.do?symbol=COM7&ssoPageId=4&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df.head(5)
# Out:
# No. of Table:  1
#                                                    0
# 0  Company Name COM7 PUBLIC COMPANY LIMITED Addre...
# 1  Trading Statistics (as of 15 Sep 2020)  P/E  3...
# 2  Market  SET  Industry  Services  Sector  Comme...
# 3  Shares Detail  Common Stock  Listed Share  1,2...
# 4  Dividend Policy  No less than 40% of the Net P...

# %%
url = 'https://www.set.or.th/set/companyhighlight.do?symbol=COM7&ssoPageId=5&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df
# Out:
# No. of Table:  1
#                    Period as of  ... Q2 '2030/06/2020
#                Statistics as of  ...       16/09/2020
# 0                Financial Data  ...              NaN
# 1                        Assets  ...          9459.31
# 2                   Liabilities  ...          6524.46
# 3                        Equity  ...          2929.92
# 4               Paid-up Capital  ...           300.00
# 5                       Revenue  ...         15970.70
# 6                    Net Profit  ...           562.39
# 7                    EPS (Baht)  ...             0.47
# 8               Financial Ratio  ...              NaN
# 9                        ROA(%)  ...            18.34
# 10                       ROE(%)  ...            43.76
# 11         Net Profit Margin(%)  ...             3.52
# 12             Statistics as of  ...       16/09/2020
# 13             Last Price(Baht)  ...            39.75
# 14                  Market Cap.  ...         47700.00
# ...

# %%
url = 'https://www.set.or.th/set/companyholder.do?symbol=COM7&ssoPageId=6&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[2]
df
# Out:
# No. of Table:  3
#     Rank                             Major Shareholders   # Shares  % Shares
# 0    1.0                            นาย สุระ คณิตทวีกุล  300655200     25.05
# 1    2.0                     MR. PONGSAK THAMMATHATAREE  201514000     16.79
# 2    3.0                           นาย บัญชา พันธุมโกมล   82415100      6.87
# 3    4.0                         MISS AREE PREECHANUKUL   40600000      3.38
# 4    5.0             กองทุนเปิด กรุงศรีหุ้นระยะยาวปันผล   30500600      2.54
# 5    6.0               บริษัท Thai NVDR Company Limited   28372970      2.36
# 6    7.0                      MR. AMNUEY PICHITPONGCHAI   20100000      1.68
# 7    8.0                    STATE STREET EUROPE LIMITED   19715165      1.64
# 8    9.0                         น.ส. อรวรรณ วิเชียรกวี   17815000      1.48
# 9   10.0                    กองทุนเปิด กรุงศรีหุ้นปันผล   14834700      1.24
# 10  11.0   SOUTH EAST ASIA UK (TYPE C) NOMINEES LIMITED   13702100      1.14
# ...

# %%
url = 'https://www.set.or.th/set/companyrights.do?symbol=COM7&ssoPageId=7&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df
# Out:
# No. of Table:  7
#                       X-Date  ...                                     Benefit Detail
# 0                08 May 2020  ...  Book Closing Date  -  Record Date  11 May 2020...
# 1          Book Closing Date  ...                                                NaN
# 2                Record Date  ...                                                NaN
# 3               Payment Date  ...                                                NaN
# 4   Dividend per Share(Baht)  ...                                                NaN
# 5           Operation Period  ...                                                NaN
# 6         Source of Dividend  ...                                                NaN
# 7                     Remark  ...                                                NaN
# 8                05 Mar 2020  ...  Book Closing Date  -  Record Date  06 Mar 2020...
# 9          Book Closing Date  ...                                                NaN
# ...

# %%
url = 'https://www.set.or.th/set/companynews.do?symbol=COM7&ssoPageId=8&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[1]
df
# Out:
# No. of Table:  2
#             Date/Time  ...  Unnamed: 4
# 0   18 Aug 2020 17:59  ...      Detail
# 1   17 Aug 2020 19:29  ...      Detail
# 2   14 Aug 2020 08:40  ...      Detail
# 3   13 Aug 2020 18:11  ...      Detail
# 4   13 Aug 2020 18:07  ...      Detail
# 5   13 Aug 2020 18:07  ...      Detail
# 6   13 Aug 2020 18:07  ...         ZIP
# 7   15 May 2020 17:59  ...      Detail
# 8   14 May 2020 20:23  ...      Detail
# 9   14 May 2020 20:22  ...         ZIP
# 10  12 May 2020 13:00  ...      Detail
# 11  27 Apr 2020 17:39  ...      Detail
# 12  03 Apr 2020 17:50  ...      Detail
# 13  23 Mar 2020 17:17  ...      Detail
# 14  23 Mar 2020 13:18  ...      Detail
# 15  24 Feb 2020 13:29  ...      Detail
# 16  24 Feb 2020 13:29  ...         ZIP
# 17  20 Feb 2020 21:06  ...      Detail
# 18  20 Feb 2020 21:05  ...      Detail
# 19  20 Feb 2020 21:04  ...      Detail
#
# [20 rows x 5 columns]

# %%
url = 'https://marketdata.set.or.th/mkt/stockquotation.do?symbol=COM7&ssoPageId=1&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df.head(5)
# Out:
# No. of Table:  3
#   * Last Update 17 Sep 2020 01:34:57
#               Market Status : Closed Market Status : Closed.1
# 0                               Sign                      NaN
# 1                               Last                    39.75
# 2                             Change                    -0.75
# 3                            %Change                    -1.85
# 4                              Prior                    40.50

# %%
url = 'https://www.set.or.th/set/historicaltrading.do?symbol=COM7&ssoPageId=2&language=en&country=US'
table = pd.read_html(url)
print("No. of Table: ", len(table))

df = table[0]
df.head(5)
# Out:
# No. of Table:  1
#          Date   Open  ...  Total Volume(Shares)  Total Value('000 Baht)
# 0  16/09/2020  40.50  ...               4037926               161685.16
# 1  15/09/2020  39.50  ...               7777050               311369.05
# 2  14/09/2020  39.25  ...              12733490               489139.77
# 3  11/09/2020  40.50  ...              12837623               504818.72
# 4  10/09/2020  41.50  ...               4249240               174330.82
#
# [5 rows x 9 columns]
